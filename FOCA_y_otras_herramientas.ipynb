# %% [markdown]
# <a href="https://colab.research.google.com/github/William-Burbano-Lima/Ciberseguridad_explorador/blob/main/FOCA_y_otras_herramientas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TALENTO TECH CIBERSEGURIDAD
#
# RECOLECCION PASIVA DE INFORMACION
#
# HERRAMIENTAS
#
# ---
# 1. FOCA (Fingerprinting Organizations with Collected Archives) es una herramienta utilizada en ciberseguridad para el análisis de metadatos en documentos. Permite identificar información sensible como usuarios, rutas de red y servidores de una organización.
#
# ## 🔹 **Instalación de FOCA**
# FOCA es una herramienta que solo está disponible para Windows y requiere .NET Framework.
#
# ### **1️⃣ Requisitos previos**
# - Windows 10 o superior
# - Microsoft .NET Framework 4.7 o superior
# - Conexión a Internet (para búsquedas en línea)
#
# ### **2️⃣ Descarga e instalación**
# 1. Visita el sitio oficial de ElevenPaths:
#    📌 [https://www.elevenpaths.com](https://www.elevenpaths.com)
#    (O busca en Google: **"FOCA ElevenPaths Download"**).
# 2. Descarga la última versión de FOCA.
# 3. Descomprime el archivo descargado.
# 4. Ejecuta `FOCA.exe` como administrador.
#
# ✅ ¡Listo! Ahora puedes comenzar a usar FOCA.
#
# ---
#
# ## 🔹 **Configuración de FOCA**
# Al iniciar FOCA, verás una interfaz con varias opciones para analizar documentos.
#
# ### **1️⃣ Configurar búsqueda de documentos**
# 1. **Agregar URL de dominio**: En la pestaña `Files`, introduce el dominio objetivo (ejemplo: `empresa.com`).
# 2. **Buscar archivos**: Usa `Search Public Files` para encontrar documentos disponibles en motores como Google, Bing o Exalead.
# 3. **Cargar archivos manualmente**: Puedes subir archivos PDF, Word, Excel o PowerPoint descargados previamente.
#
# ### **2️⃣ Opciones avanzadas**
# - Configurar **proxys** para anonimizar las búsquedas.
# - Habilitar la opción `Deep Search` para análisis más profundos.
# - Integrar con **Shodan** para obtener información adicional sobre servidores y direcciones IP.
#
# ---
#
# ## 🔹 **Ejemplos de uso de FOCA**
# ### **1️⃣ Extracción de metadatos de documentos**
# 📌 **Ejemplo**: Descargar y analizar archivos de un dominio gubernamental.
#
# 1. Agrega el dominio `gobierno.com`.
# 2. Busca documentos públicos (`.pdf`, `.docx`, `.pptx`).
# 3. Descarga los archivos encontrados.
# 4. FOCA extraerá datos como:
#    - Autores del documento.
#    - Software utilizado para crear el documento.
#    - Ruta del archivo en la computadora de origen (`C:\Users\Admin\Documents\Report.pdf`).
#    - Dirección IP interna de la organización.
#
# 🔍 **Resultado:**
# Se identifican nombres de usuarios y rutas de red internas, lo que puede ayudar en una auditoría de seguridad.
#
# ---
#
# ## 🔹 **Ejercicios prácticos**
# ### **Ejercicio 1: Análisis básico de documentos**
# 1. Descarga un documento público desde el sitio web de una empresa.
# 2. Cárgalo en FOCA y analiza los metadatos.
# 3. Identifica:
#    - Nombres de autores.
#    - Versión de software utilizada.
#    - Información de red (si está disponible).
#
# 📌 **Objetivo:** Entender cómo los metadatos pueden filtrar información sensible.
#
# ---
#
# ### **Ejercicio 2: Búsqueda de documentos en Google**
# FOCA usa **dorks de Google** para encontrar archivos. Prueba manualmente con:
#
# ```
# site:empresa.com filetype:pdf
# ```
#
# 1. Encuentra documentos en un dominio público.
# 2. Descarga un archivo.
# 3. Analízalo con FOCA.
#
# 📌 **Objetivo:** Aprender cómo los motores de búsqueda pueden exponer información confidencial.
#
# ---
#
# ### **Ejercicio 3: Uso de proxys en FOCA**
# 1. Configura un proxy en FOCA (`Settings > Proxy`).
# 2. Repite el análisis usando una VPN.
# 3. Compara los resultados.
#
# 📌 **Objetivo:** Proteger tu identidad al realizar análisis de metadatos.
#
# ---
#
# #LABORATORIO 2
#
# Aquí tienes ejemplos avanzados y ejercicios prácticos con **FOCA**, incluyendo técnicas para extraer información oculta en documentos y análisis forense en ciberseguridad.
#
# ---
#
# # 🔹 **Ejemplos prácticos avanzados con FOCA**
#
# ## **📌 Ejemplo 1: Identificación de usuarios internos en una organización**
# ### **Objetivo:**
# Extraer nombres de usuario y rutas internas de documentos en un dominio corporativo.
#
# ### **Pasos:**
# 1. **Añadir el dominio de la empresa** (ejemplo: `empresa.com`) en FOCA.
# 2. **Buscar documentos públicos** en motores de búsqueda (`Google`, `Bing`, `Exalead`).
# 3. **Descargar y analizar archivos** (`PDF`, `Word`, `Excel`).
# 4. **Revisar los metadatos** para encontrar:
#    - Nombres de autores y usuarios internos.
#    - Rutas de archivo (ejemplo: `C:\Users\JuanAdmin\Documents\Report.docx`).
#    - Versión del software utilizado.
# 5. **Crear un mapa de usuarios** potencialmente vinculados a la empresa.
#
# ### **Resultado esperado:**
# - Identificación de usuarios internos (`JuanAdmin`, `MariaContabilidad`).
# - Descubrimiento de rutas internas en la red de la organización.
# - Conocimiento de versiones de software para posibles vulnerabilidades.
#
# 🔍 **Casos de uso:**
# - Pentesting para auditoría de seguridad.
# - Análisis de filtración de información en documentos públicos.
#
# ---
#
# ## **📌 Ejemplo 2: Análisis de documentos con OCR (Reconocimiento Óptico de Caracteres)**
# ### **Objetivo:**
# Extraer texto oculto en imágenes dentro de documentos PDF.
#
# ### **Pasos:**
# 1. **Descargar archivos PDF con imágenes incrustadas** desde un sitio web gubernamental o corporativo.
# 2. **Subirlos a FOCA** y analizar metadatos básicos.
# 3. **Utilizar herramientas adicionales de OCR** (`Tesseract OCR` o `ABBYY FineReader`) para extraer texto de imágenes dentro del PDF.
# 4. **Buscar información sensible**, como correos electrónicos, números de teléfono o direcciones IP.
#
# ### **Resultado esperado:**
# - Descubrir datos ocultos en imágenes dentro de documentos PDF.
# - Identificar información que podría ser utilizada en ingeniería social.
#
# 🔍 **Casos de uso:**
# - Análisis de documentos filtrados.
# - Recuperación de información en auditorías de seguridad.
#
# ---
#
# # 🔹 **Ejercicios avanzados con FOCA**
#
# ## **🛠 Ejercicio 1: Creación de un diccionario de usuarios para ataques de fuerza bruta**
# ### **Objetivo:**
# Generar una lista de posibles nombres de usuario extraídos de documentos públicos para pruebas de pentesting.
#
# ### **Pasos:**
# 1. **Extraer metadatos de varios archivos** de un dominio (`empresa.com`).
# 2. **Registrar los nombres de usuario** encontrados (`JuanAdmin`, `MariaHR`, `CarlosIT`).
# 3. **Generar un diccionario de usuarios** y guardarlo en un archivo `.txt`.
# 4. **Usarlo en ataques de fuerza bruta** con `Hydra` o `Medusa`.
#
# ### **Ejemplo de archivo de diccionario (`users.txt`):**
# ```
# JuanAdmin
# MariaHR
# CarlosIT
# ```
#
# ✅ **Resultado esperado:**
# - Un diccionario realista basado en usuarios internos.
# - Un recurso útil para pruebas de acceso en pentesting.
#
# ---
#
# ## **🛠 Ejercicio 2: Detección de información oculta en archivos ofimáticos**
# ### **Objetivo:**
# Descubrir versiones antiguas de documentos y datos eliminados.
#
# ### **Pasos:**
# 1. **Descargar documentos Word o Excel de un sitio web público.**
# 2. **Usar FOCA para extraer metadatos.**
# 3. **Abrir los archivos con herramientas forenses** como `DocScrubber` o `ExifTool`.
# 4. **Buscar información en "Revisiones de documento"**, incluyendo autores anteriores y cambios ocultos.
#
# ✅ **Resultado esperado:**
# - Recuperación de información eliminada en versiones anteriores.
# - Descubrimiento de datos internos en documentos mal gestionados.
#
# ---
#
# ## **🛠 Ejercicio 3: Creación de un informe de vulnerabilidades basado en metadatos**
# ### **Objetivo:**
# Realizar un informe detallado con riesgos identificados a partir del análisis de documentos públicos.
#
# ### **Pasos:**
# 1. **Analizar múltiples archivos** de una organización (`empresa.com`).
# 2. **Extraer información clave**, como versiones de software, usuarios y servidores internos.
# 3. **Comparar con bases de datos de vulnerabilidades** (`CVE`, `ExploitDB`).
# 4. **Redactar un informe de seguridad**, incluyendo:
#    - **Usuarios y rutas internas identificadas.**
#    - **Software usado y posibles vulnerabilidades.**
#    - **Recomendaciones para mitigar riesgos.**
#
# 📌 **Ejemplo de informe:**
# ```
# 🛡 Informe de Seguridad - Análisis de Metadatos con FOCA
# ---------------------------------------------------------
# 🔹 Usuarios internos detectados: JuanAdmin, MariaHR
# 🔹 Software identificado: Microsoft Word 2013 (Vulnerabilidad CVE-2017-0199)
# 🔹 Riesgo potencial: Ataques de phishing dirigidos con exploits de Office
# 🔹 Recomendaciones: Actualizar software y eliminar metadatos en documentos públicos
# ```
#
# ✅ **Resultado esperado:**
# - Un reporte técnico con hallazgos relevantes para mejorar la seguridad organizacional.
#
#
# # 🔹 **Conclusión**
# FOCA es una herramienta poderosa para análisis forense y auditoría de seguridad. Con estos ejemplos y ejercicios avanzados, puedes mejorar tus habilidades en ciberseguridad y detectar posibles filtraciones de datos en documentos públicos, es una herramienta poderosa en auditoría de seguridad, permitiendo extraer información sensible de documentos públicos. Su uso adecuado ayuda a comprender cómo las organizaciones pueden filtrar datos involuntariamente.
#
# ---
#
# #RESUMEN LISTADO DE LAS PRINCIPALES HERRAMIENTAS PARA RECOLECCION DE INFORMACION PASIVA
#
# ### 🔍 **Herramientas Complementarias para Recolección de Información Pasiva en Ciberseguridad**
#
# La **recolección de información pasiva** es clave en la fase de reconocimiento de **OSINT (Open Source Intelligence)**. Con estas herramientas podemos obtener datos sin interactuar directamente con los sistemas objetivo.
#
# ---
#
# ## **🛠 1. Herramientas para análisis de metadatos**
#
# ### 📌 **FOCA**
# - Extrae metadatos de documentos (`PDF, DOCX, PPTX, XLSX`).
# - Revela usuarios, rutas internas, software y versiones.
# - Descarga y analiza documentos de sitios web.
# - **Uso:** Auditoría de seguridad en documentos públicos.
#
# 🔗 [Descargar FOCA](https://elevenpaths.com/labstools/foca/)
#
# ### 📌 **ExifTool**
# - Extrae metadatos de imágenes (`JPG, PNG, TIFF, RAW`).
# - Obtiene datos EXIF (modelo de cámara, ubicación GPS, fecha).
# - **Uso:** Identificar información oculta en fotos filtradas.
#
# 📌 **Comando:**
# ```bash
# exiftool imagen.jpg
# ```
# 🔗 [Descargar ExifTool](https://exiftool.org/)
#
# ### 📌 **DocScrubber**
# - Analiza y limpia metadatos en documentos `Word`.
# - Identifica revisiones de documentos, autores y versiones.
# - **Uso:** Prevenir filtraciones de datos en archivos compartidos.
#
# 🔗 [Descargar DocScrubber](https://www.brightfort.com/docscrubber.html)
#
# ---
#
# ## **🛠 2. Herramientas para análisis de dominios y DNS**
#
# ### 📌 **WHOIS**
# - Obtiene información de dominios (`dueño, emails, fechas de creación`).
# - **Uso:** Identificar responsables de un sitio web.
#
# 📌 **Comando:**
# ```bash
# whois ejemplo.com
# ```
# 🔗 [Consultar WHOIS online](https://who.is/)
#
# ### 📌 **Nslookup & Dig**
# - Resuelve direcciones IP de un dominio.
# - Obtiene registros `MX`, `TXT`, `NS`, `CNAME`.
# - **Uso:** Descubrir servidores de correo y configuraciones DNS.
#
# 📌 **Comando:**
# ```bash
# nslookup -type=mx ejemplo.com
# dig txt ejemplo.com
# ```
#
# ### 📌 **Sublist3r**
# - Encuentra subdominios de un dominio.
# - Usa motores de búsqueda (`Google, Bing, Yahoo`).
# - **Uso:** Mapear la infraestructura de una empresa.
#
# 📌 **Comando:**
# ```bash
# python sublist3r.py -d ejemplo.com
# ```
# 🔗 [GitHub Sublist3r](https://github.com/aboul3la/Sublist3r)
#
# ### 📌 **Amass**
# - Descubre subdominios y analiza relaciones en infraestructuras.
# - Usa técnicas de OSINT y bases de datos de inteligencia.
# - **Uso:** Identificar activos ocultos de un dominio.
#
# 📌 **Comando:**
# ```bash
# amass enum -d ejemplo.com
# ```
# 🔗 [GitHub Amass](https://github.com/OWASP/Amass)
#
# ---
#
# ## **🛠 3. Herramientas para análisis de direcciones IP**
#
# ### 📌 **Shodan**
# - Escanea dispositivos conectados a internet (`cámaras, servidores, IoT`).
# - Identifica puertos abiertos y software vulnerable.
# - **Uso:** Detectar dispositivos expuestos con vulnerabilidades conocidas.
#
# 🔗 [Shodan.io](https://www.shodan.io/)
#
# 📌 **Ejemplo de búsqueda:**
# ```
# apache country:ES
# ```
#
# ### 📌 **Censys**
# - Similar a Shodan, pero con más detalles en certificados SSL.
# - **Uso:** Buscar servidores con configuraciones débiles.
#
# 🔗 [Censys.io](https://search.censys.io/)
#
# ### 📌 **IPinfo**
# - Obtiene datos de una IP (`ISP, ubicación, ASN`).
# - **Uso:** Identificar la ubicación y red de un objetivo.
#
# 📌 **Comando:**
# ```bash
# curl ipinfo.io/8.8.8.8
# ```
# 🔗 [IPinfo.io](https://ipinfo.io/)
#
# ---
#
# ## **🛠 4. Herramientas para recolección de correos electrónicos y filtraciones**
#
# ### 📌 **theHarvester**
# - Busca correos, subdominios, hosts y datos de una empresa.
# - Usa fuentes públicas como `Google, Bing, LinkedIn`.
# - **Uso:** Recolectar información para ingeniería social.
#
# 📌 **Comando:**
# ```bash
# theHarvester -d ejemplo.com -b google
# ```
# 🔗 [GitHub theHarvester](https://github.com/laramies/theHarvester)
#
# ### 📌 **Holehe**
# - Verifica si un correo está registrado en redes sociales.
# - **Uso:** Identificar presencia digital de un usuario.
#
# 📌 **Comando:**
# ```bash
# holehe correo@gmail.com
# ```
# 🔗 [GitHub Holehe](https://github.com/megadose/holehe)
#
# ### 📌 **Have I Been Pwned?**
# - Verifica si un correo ha sido filtrado en brechas de datos.
# - **Uso:** Descubrir credenciales expuestas.
#
# 🔗 [Have I Been Pwned](https://haveibeenpwned.com/)
#
# ---
#
# ## **🛠 5. Herramientas para inteligencia en redes sociales (SOCMINT)**
#
# ### 📌 **SpiderFoot**
# - Analiza redes sociales, filtraciones de datos y más.
# - **Uso:** Automatiza la recolección de información OSINT.
#
# 🔗 [GitHub SpiderFoot](https://github.com/smicallef/spiderfoot)
#
# ### 📌 **Maltego**
# - Genera gráficos de relaciones entre personas, empresas y direcciones IP.
# - **Uso:** Investigación en ciberseguridad y análisis forense.
#
# 🔗 [Maltego](https://www.maltego.com/)
#
# ### 📌 **Sherlock**
# - Busca nombres de usuario en múltiples redes sociales.
# - **Uso:** Rastrear actividad en redes de un objetivo.
#
# 📌 **Comando:**
# ```bash
# python3 sherlock.py username
# ```
# 🔗 [GitHub Sherlock](https://github.com/sherlock-project/sherlock)
#
# ---
#
# ## **🚀 Conclusión**
#
# Estas herramientas nos permiten realizar **recolección de información pasiva** sin alertar al objetivo. Se usan en **pentesting, auditorías de seguridad y OSINT** para evaluar riesgos y vulnerabilidades.
# ---
# &copy; Análisis y resumen de información de varias fuentes libres en internet realizada por *William Burbano Lima*
#
# Ejecutor Técnico Ciberguridad Talento Tech MINTIC Gobierno de Colombia.
